# %%
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm

# %%
import spacy
from spacy import displacy
from pathlib import Path

nlp = spacy.load('en_core_web_sm')

def highlight_root(sentence):
  doc = nlp(sentence)
  
  # Find the root of the sentence
  root = None
  for token in doc:
    if token.dep_ == 'ROOT':
      root = token
      break
  
  # Highlight the root entity in the output
  if root is not None:
    root_start = root.idx
    root_end = root.idx + len(root.text)
  
    text = [{
      'text': sentence,
      'ents': [{
        'start': root_start,
        'end': root_end,
        'label': '',
      }],
      'title': None
    }]
    displacy.render(text, style='ent', manual=True)
  else:
      print("No root found.")
  return root

# %%
sentence = "The spectacular aurora light displays that appear in Earth’s atmosphere around the north and south magnetic poles were once mysterious phenomena."

doc = nlp(sentence)

# %%
# 标注每个单词的词性

for token in doc:
  print(token.text, token.pos_)
# Out:
# The DET
# spectacular ADJ
# aurora NOUN
# light NOUN
# displays NOUN
# that PRON
# appear VERB
# in ADP
# Earth PROPN
# ’s PART
# atmosphere NOUN
# around ADP
# the DET
# north NOUN
# and CCONJ
# south ADJ
# magnetic ADJ
# poles NOUN
# were AUX
# once ADV
# mysterious ADJ
# phenomena NOUN
# . PUNCT

# %%
# 高亮标注主句的谓语动词

root = highlight_root(sentence)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The spectacular aurora light displays that appear in Earth’s atmosphere around the north and south magnetic poles
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     were
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  once mysterious phenomena.</div></span>

# %%
# 主句的简化版本

children = list(root.children)
children.insert(1, root)
simplified_setence = ' '.join(str(c) for c in children).strip().replace(" .", ".").capitalize()

print(simplified_setence)
# Out:
# Displays were once phenomena.

# %%
# 图形化显示句子成分之间的依赖关系

displacy.render(doc, style="dep", options={'distance': 60})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="fefdcb037e4145ada8519f4ace3d100b-0" class="displacy" width="1370" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="110">spectacular</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="110">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">aurora</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">light</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">displays</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">appear</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Earth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">atmosphere</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">around</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="830">north</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="830">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">south</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">magnetic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1070">poles</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1070">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">were</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1190">once</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1190">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">mysterious</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">phenomena.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fefdcb037e4145ada8519f4ace3d100b-0-0" stroke-width="2px" d="M70,182.0 C70,92.0 275.0,92.0 275.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fefdcb037e4145ada8519f4ace3d100b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fefdcb037e4145ada8519f4ace3d100b-0-1" stroke-width="2px" d="M130,182.0 C130,122.0 270.0,122.0 270.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fefdcb037e4145ada8519f4ace3d100b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M130,184.0 L122,172.0 138,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fefdcb037e4145ada8519f4ace3d100b-0-2" stroke-width="2px" d="M190,182.0 C190,152.0 205.0,152.0 205.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fefdcb037e4145ada8519f4ace3d100b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fefdcb037e4145ada8519f4ace3d100b-0-3" stroke-width="2px" d="M250,182.0 C250,152.0 265.0,152.0 265.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fefdcb037e4145ada8519f4ace3d100b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </te

# %%
# 将图形保存为 dep-graph.svg 文件

svg = displacy.render(doc, style="dep", jupyter=False)
output_path = Path("dep-graph.svg")
output_path.open("w", encoding="utf-8").write(svg)
